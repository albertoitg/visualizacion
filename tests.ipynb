# %%
import pandas as pd

# %%
data = pd.read_csv("data/D_MATRICULA_PAES_2025_PUB_MRUN.csv", delimiter=";")

# %%
data["MRUN"].head(10)
# Out:
# 0     534
# 1     535
# 2     752
# 3     978
# 4    1259
# 5    1260
# 6    1342
# 7    1479
# 8    1812
# 9    1882
# Name: MRUN, dtype: int64

# %%
socio = pd.read_csv("data/B_SOCIOECONOMICO_DOMICILIO_PAES_2025_PUB_MRUN.csv", delimiter=";")

# %%
socio.head(10)
# Out:
#    MRUN  ANYO_PROCESO  CODIGO_REGION_DOMICILIO  CODIGO_PROVINCIA_DOMICILIO  \
# 0   214          2025                       16                         161
# 1   492          2025                       12                         121
# 2   534          2025                        6                          63
# 3   535          2025                        8                          81
# 4   752          2025                       15                         151
# 5   978          2025                       13                         131
# 6  1236          2025                       13                         131
# 7  1255          2025                       13                         136
# 8  1259          2025                       13                         135
# 9  1260          2025                        6                          61
#
#    CODIGO_COMUNA_DOMICILIO NOMBRE_COMUNA_DOMICILIO  SEXO  FECHA_NACIMIENTO  \
# ...

# %%
common = set(data['MRUN']) & set(socio['MRUN'])
print(f"Common MRUNs: {len(common)} / {data['MRUN'].nunique()} in matriculas")
# Out:
# Common MRUNs: 136220 / 140687 in matriculas
